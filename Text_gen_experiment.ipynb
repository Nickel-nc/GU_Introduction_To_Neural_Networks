# %% [markdown]
# ## Contents
#
# * [Numpy RNN, implementation 'Uspensky' text](#numpy)

# %%
import numpy as np
import sys, random, math
from collections import Counter

# %% [markdown]
# ## Numpy RNN, implementation 'Uspensky' text
# <a class="anchor" id="numpy"></a>

# %%
# Фреймворк, предложенный Э. Траском

class Tensor (object):
    
    def __init__(self,data,
                 autograd=False,
                 creators=None,
                 creation_op=None,
                 id=None):
        
        self.data = np.array(data)
        self.autograd = autograd
        self.grad = None

        if(id is None):
            self.id = np.random.randint(0,1000000000)
        else:
            self.id = id
        
        self.creators = creators
        self.creation_op = creation_op
        self.children = {}
        
        if(creators is not None):
            for c in creators:
                if(self.id not in c.children):
                    c.children[self.id] = 1
                else:
                    c.children[self.id] += 1

    def all_children_grads_accounted_for(self):
        for id,cnt in self.children.items():
            if(cnt != 0):
                return False
        return True 
        
    def backward(self,grad=None, grad_origin=None):
        if(self.autograd):
 
            if(grad is None):
                grad = Tensor(np.ones_like(self.data))

            if(grad_origin is not None):
                if(self.children[grad_origin.id] == 0):
                    return
                    print(self.id)
                    print(self.creation_op)
                    print(len(self.creators))
                    for c in self.creators:
                        print(c.creation_op)
                    raise Exception("cannot backprop more than once")
                else:
                    self.children[grad_origin.id] -= 1

            if(self.grad is None):
                self.grad = grad
            else:
                self.grad += grad
            
            # grads must not have grads of their own
            assert grad.autograd == False
            
            # only continue backpropping if there's something to
            # backprop into and if all gradients (from children)
            # are accounted for override waiting for children if
            # "backprop" was called on this variable directly
            if(self.creators is not None and 
               (self.all_children_grads_accounted_for() or 
                grad_origin is None)):

                if(self.creation_op == "add"):
                    self.creators[0].backward(self.grad, self)
                    self.creators[1].backward(self.grad, self)
                    
                if(self.creation_op == "sub"):
                    self.creators[0].backward(Tensor(self.grad.data), self)
                    self.creators[1].backward(Tensor(self.grad.__neg__().data), self)

                if(self.creation_op == "mul"):
                    new = self.grad * self.creators[1]
                    self.creators[0].backward(new , self)
                    new = self.grad * self.creators[0]
                    self.creators[1].backward(new, self)                    
                    
                if(self.creation_op == "mm"):
                    c0 = self.creators[0]
                    c1 = self.creators[1]
                    new = self.grad.mm(c1.transpose())
                    c0.backward(new)
                    new = self.grad.transpose().mm(c0).transpose()
                    c1.backward(new)
                    
                if(self.creation_op == "transpose"):
                    self.creators[0].backward(self.grad.transpose())

                if("sum" in self.creation_op):
                    dim = int(self.creation_op.split("_")[1])
                    self.creators[0].backward(self.grad.expand(dim,
                                                               self.creators[0].data.shape[dim]))

                if("expand" in self.creation_op):
                    dim = int(self.creation_op.split("_")[1])
                    self.creators[0].backward(self.grad.sum(dim))
                    
                if(self.creation_op == "neg"):
                    self.creators[0].backward(self.grad.__neg__())
                    
                if(self.creation_op == "sigmoid"):
                    ones = Tensor(np.ones_like(self.grad.data))
                    self.creators[0].backward(self.grad * (self * (ones - self)))
                
                if(self.creation_op == "tanh"):
                    ones = Tensor(np.ones_like(self.grad.data))
                    self.creators[0].backward(self.grad * (ones - (self * self)))
                
                if(self.creation_op == "index_select"):
                    new_grad = np.zeros_like(self.creators[0].data)
                    indices_ = self.index_select_indices.data.flatten()
                    grad_ = grad.data.reshape(len(indices_), -1)
                    for i in range(len(indices_)):
                        new_grad[indices_[i]] += grad_[i]
                    self.creators[0].backward(Tensor(new_grad))
                    
                if(self.creation_op == "cross_entropy"):
                    dx = self.softmax_output - self.target_dist
                    self.creators[0].backward(Tensor(dx))
                    
    def __add__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data + other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="add")
        return Tensor(self.data + other.data)

    def __neg__(self):
        if(self.autograd):
            return Tensor(self.data * -1,
                          autograd=True,
                          creators=[self],
                          creation_op="neg")
        return Tensor(self.data * -1)
    
    def __sub__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data - other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="sub")
        return Tensor(self.data - other.data)
    
    def __mul__(self, other):
        if(self.autograd and other.autograd):
            return Tensor(self.data * other.data,
                          autograd=True,
                          creators=[self,other],
                          creation_op="mul")
        return Tensor(self.data * other.data)    

    def sum(self, dim):
        if(self.autograd):
            return Tensor(self.data.sum(dim),
                          autograd=True,
                          creators=[self],
                          creation_op="sum_"+str(dim))
        return Tensor(self.data.sum(dim))
    
    def expand(self, dim,copies):

        trans_cmd = list(range(0,len(self.data.shape)))
        trans_cmd.insert(dim,len(self.data.shape))
        new_data = self.data.repeat(copies).reshape(list(self.data.shape) + [copies]).transpose(trans_cmd)
        
        if(self.autograd):
            return Tensor(new_data,
                          autograd=True,
                          creators=[self],
                          creation_op="expand_"+str(dim))
        return Tensor(new_data)
    
    def transpose(self):
        if(self.autograd):
            return Tensor(self.data.transpose(),
                          autograd=True,
                          creators=[self],
                          creation_op="transpose")
        
        return Tensor(self.data.transpose())
    
    def mm(self, x):
        if(self.autograd):
            return Tensor(self.data.dot(x.data),
                          autograd=True,
                          creators=[self,x],
                          creation_op="mm")
        return Tensor(self.data.dot(x.data))
    
    def sigmoid(self):
        if(self.autograd):
            return Tensor(1 / (1 + np.exp(-self.data)),
                          autograd=True,
                          creators=[self],
                          creation_op="sigmoid")
        return Tensor(1 / (1 + np.exp(-self.data)))

    def tanh(self):
        if(self.autograd):
            return Tensor(np.tanh(self.data),
                          autograd=True,
                          creators=[self],
                          creation_op="tanh")
        return Tensor(np.tanh(self.data))
    
    def index_select(self, indices):

        if(self.autograd):
            new = Tensor(self.data[indices.data],
                         autograd=True,
                         creators=[self],
                         creation_op="index_select")
            new.index_select_indices = indices
            return new
        return Tensor(self.data[indices.data])
    
    def softmax(self):
        temp = np.exp(self.data)
        softmax_output = temp / np.sum(temp,
                                       axis=len(self.data.shape)-1,
                                       keepdims=True)
        return softmax_output
    
    def cross_entropy(self, target_indices):

        temp = np.exp(self.data)
        softmax_output = temp / np.sum(temp,
                                       axis=len(self.data.shape)-1,
                                       keepdims=True)
        
        t = target_indices.data.flatten()
        p = softmax_output.reshape(len(t),-1)
        target_dist = np.eye(p.shape[1])[t]
        loss = -(np.log(p) * (target_dist)).sum(1).mean()
    
        if(self.autograd):
            out = Tensor(loss,
                         autograd=True,
                         creators=[self],
                         creation_op="cross_entropy")
            out.softmax_output = softmax_output
            out.target_dist = target_dist
            return out

        return Tensor(loss)
        
    
    def __repr__(self):
        return str(self.data.__repr__())
    
    def __str__(self):
        return str(self.data.__str__())  

class Layer(object):
    
    def __init__(self):
        self.parameters = list()
        
    def get_parameters(self):
        return self.parameters

    
class SGD(object):
    
    def __init__(self, parameters, alpha=0.1):
        self.parameters = parameters
        self.alpha = alpha
    
    def zero(self):
        for p in self.parameters:
            p.grad.data *= 0
        
    def step(self, zero=True):
        
        for p in self.parameters:
            
            p.data -= p.grad.data * self.alpha
            
            if(zero):
                p.grad.data *= 0


class Linear(Layer):

    def __init__(self, n_inputs, n_outputs, bias=True):
        super().__init__()
        
        self.use_bias = bias
        
        W = np.random.randn(n_inputs, n_outputs) * np.sqrt(2.0/(n_inputs))
        self.weight = Tensor(W, autograd=True)
        if(self.use_bias):
            self.bias = Tensor(np.zeros(n_outputs), autograd=True)
        
        self.parameters.append(self.weight)
        
        if(self.use_bias):        
            self.parameters.append(self.bias)

    def forward(self, input):
        if(self.use_bias):
            return input.mm(self.weight)+self.bias.expand(0,len(input.data))
        return input.mm(self.weight)


class Sequential(Layer):
    
    def __init__(self, layers=list()):
        super().__init__()
        
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
        
    def forward(self, input):
        for layer in self.layers:
            input = layer.forward(input)
        return input
    
    def get_parameters(self):
        params = list()
        for l in self.layers:
            params += l.get_parameters()
        return params


class Embedding(Layer):
    
    def __init__(self, vocab_size, dim):
        super().__init__()
        
        self.vocab_size = vocab_size
        self.dim = dim
        
        # this random initialiation style is just a convention from word2vec
        self.weight = Tensor((np.random.rand(vocab_size, dim) - 0.5) / dim, autograd=True)
        
        self.parameters.append(self.weight)
    
    def forward(self, input):
        return self.weight.index_select(input)


class Tanh(Layer):
    def __init__(self):
        super().__init__()
    
    def forward(self, input):
        return input.tanh()


class Sigmoid(Layer):
    def __init__(self):
        super().__init__()
    
    def forward(self, input):
        return input.sigmoid()
    

class CrossEntropyLoss(object):
    
    def __init__(self):
        super().__init__()
    
    def forward(self, input, target):
        return input.cross_entropy(target)

    
class RNNCell(Layer):
    
    def __init__(self, n_inputs, n_hidden, n_output, activation='sigmoid'):
        super().__init__()

        self.n_inputs = n_inputs
        self.n_hidden = n_hidden
        self.n_output = n_output
        
        if(activation == 'sigmoid'):
            self.activation = Sigmoid()
        elif(activation == 'tanh'):
            self.activation == Tanh()
        else:
            raise Exception("Non-linearity not found")

        self.w_ih = Linear(n_inputs, n_hidden)
        self.w_hh = Linear(n_hidden, n_hidden)
        self.w_ho = Linear(n_hidden, n_output)
        
        self.parameters += self.w_ih.get_parameters()
        self.parameters += self.w_hh.get_parameters()
        self.parameters += self.w_ho.get_parameters()        
    
    def forward(self, input, hidden):
        from_prev_hidden = self.w_hh.forward(hidden)
        combined = self.w_ih.forward(input) + from_prev_hidden
        new_hidden = self.activation.forward(combined)
        output = self.w_ho.forward(new_hidden)
        return output, new_hidden
    
    def init_hidden(self, batch_size=1):
        return Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
    
class LSTMCell(Layer):
    
    def __init__(self, n_inputs, n_hidden, n_output):
        super().__init__()

        self.n_inputs = n_inputs
        self.n_hidden = n_hidden
        self.n_output = n_output

        self.xf = Linear(n_inputs, n_hidden)
        self.xi = Linear(n_inputs, n_hidden)
        self.xo = Linear(n_inputs, n_hidden)        
        self.xc = Linear(n_inputs, n_hidden)        
        
        self.hf = Linear(n_hidden, n_hidden, bias=False)
        self.hi = Linear(n_hidden, n_hidden, bias=False)
        self.ho = Linear(n_hidden, n_hidden, bias=False)
        self.hc = Linear(n_hidden, n_hidden, bias=False)        
        
        self.w_ho = Linear(n_hidden, n_output, bias=False)
        
        self.parameters += self.xf.get_parameters()
        self.parameters += self.xi.get_parameters()
        self.parameters += self.xo.get_parameters()
        self.parameters += self.xc.get_parameters()

        self.parameters += self.hf.get_parameters()
        self.parameters += self.hi.get_parameters()        
        self.parameters += self.ho.get_parameters()        
        self.parameters += self.hc.get_parameters()                
        
        self.parameters += self.w_ho.get_parameters()        
    
    def forward(self, input, hidden):
        
        prev_hidden = hidden[0]        
        prev_cell = hidden[1]
        
        f = (self.xf.forward(input) + self.hf.forward(prev_hidden)).sigmoid()
        i = (self.xi.forward(input) + self.hi.forward(prev_hidden)).sigmoid()
        o = (self.xo.forward(input) + self.ho.forward(prev_hidden)).sigmoid()        
        g = (self.xc.forward(input) + self.hc.forward(prev_hidden)).tanh()        
        c = (f * prev_cell) + (i * g)

        h = o * c.tanh()
        
        output = self.w_ho.forward(h)
        return output, (h, c)
    
    def init_hidden(self, batch_size=1):
        init_hidden = Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
        init_cell = Tensor(np.zeros((batch_size,self.n_hidden)), autograd=True)
        init_hidden.data[:,0] += 1
        init_cell.data[:,0] += 1
        return (init_hidden, init_cell)

# %% [markdown]
# ### RNN CELL MODEL

# %%
np.random.seed(0)

f = open('Tam_gde_nas_net.txt','r')
raw = f.read()
f.close()
vocab = list(set(raw))
word2index = {}
for i,word in enumerate(vocab):
    word2index[word]=i
indices = np.array(list(map(lambda x:word2index[x], raw)))

embed = Embedding(vocab_size=len(vocab),dim=512)
model = RNNCell(n_inputs=512, n_hidden=512, n_output=len(vocab))

criterion = CrossEntropyLoss()
optim = SGD(parameters=model.get_parameters() + embed.get_parameters(), alpha=0.05)

batch_size = 32
bptt = 16
n_batches = int((indices.shape[0] / (batch_size)))

trimmed_indices = indices[:n_batches*batch_size]
batched_indices = trimmed_indices.reshape(batch_size, n_batches).transpose()

input_batched_indices = batched_indices[0:-1]
target_batched_indices = batched_indices[1:]

n_bptt = int(((n_batches-1) / bptt))
input_batches = input_batched_indices[:n_bptt*bptt].reshape(n_bptt,bptt,batch_size)
target_batches = target_batched_indices[:n_bptt*bptt].reshape(n_bptt, bptt, batch_size)

# %%
raw[:100]
# Out:
# '   ЧАСТЬ ПЕРВАЯ\n   ГЛАВА ПЕРВАЯ\n   Рекомендуется сервировать стол одинаковыми приборами и посудой од'

# %%
def train(iterations=400):
    for iter in range(iterations):
        total_loss = 0
        n_loss = 0

        hidden = model.init_hidden(batch_size=batch_size)
        for batch_i in range(len(input_batches)):

            hidden = Tensor(hidden.data, autograd=True)
            loss = None
            losses = list()
            for t in range(bptt):
                input = Tensor(input_batches[batch_i][t], autograd=True)
                rnn_input = embed.forward(input=input)
                output, hidden = model.forward(input=rnn_input, hidden=hidden)

                target = Tensor(target_batches[batch_i][t], autograd=True)    
                batch_loss = criterion.forward(output, target)
                losses.append(batch_loss)
                if(t == 0):
                    loss = batch_loss
                else:
                    loss = loss + batch_loss
            for loss in losses:
                ""
            loss.backward()
            optim.step()
            total_loss += loss.data
            log = "\r Iter:" + str(iter)
            log += " - Batch "+str(batch_i+1)+"/"+str(len(input_batches))
            log += " - Loss:" + str(np.exp(total_loss / (batch_i+1)))
            if(batch_i == 0):
                log += " - " + generate_sample(n=70, init_char='\n').replace("\n"," ")
            if(batch_i % 10 == 0 or batch_i-1 == len(input_batches)):
                sys.stdout.write(log)
        optim.alpha *= 0.99
        print()


def generate_sample(n=30, init_char=' '):
    s = ""
    hidden = model.init_hidden(batch_size=1)
    input = Tensor(np.array([word2index[init_char]]))
    for i in range(n):
        rnn_input = embed.forward(input)
        output, hidden = model.forward(input=rnn_input, hidden=hidden)
        output.data *= 10
        temp_dist = output.softmax()
        temp_dist /= temp_dist.sum()

        m = (temp_dist > np.random.rand()).argmax()
#         m = output.data.argmax()
        c = vocab[m]
        input = Tensor(np.array([m]))
        s += c
    return s

# %%
train(100)
# Out:
#  Iter:0 - Batch 2411/2415 - Loss:14.358499860966182о со Мр ороророМоророМоМороролроМороМоМлролМоМММлМроМороМоММроМлророло
#  Iter:1 - Batch 2411/2415 - Loss:10.550382880026433  – ВМихМу МудМу МуднМо в раМММММММу МудМММММу кМиМ ра МудМу Мудно Му
#  Iter:2 - Batch 2411/2415 - Loss:9.546120274000153  – В Муди продно продно продно продно Мудно нМи продно продно продно
#  Iter:3 - Batch 2411/2415 - Loss:8.934746329601081   – ВМадиММу Муди нМу Муди Муди Муди не продно ни продно нМуМи не про
#  Iter:4 - Batch 2411/2415 - Loss:8.490020902239655    Мудит МудитМуМи нМу кнМородит простороММу и Мудит простМут просторо
#  Iter:5 - Batch 2411/2415 - Loss:8.137469699742551    кМуди на простородит и Мудит МудиМ МудиМ Мудир простМут ММатМую кни
#  Iter:6 - Batch 2411/2415 - Loss:7.8374133795775125 круМу и Миродир Мно Мно просторолу и разна на просторолу и МиМу и п
#  Iter:7 - Batch 2411/2415 - Loss:7.5720628683692275 нМ просторолу просторолМо простММалМо просторолМо просторолМо прост
#  Iter:8 - Batch 2411/2415 - Loss:7.3322470828320495  Мутить и Мутить и ММернул Жихарь и Мутить и простММат и Мутить и пр
#  Iter:9 - Batch 2411/2415 - Loss:7.1102754141622655  разна и Мутить и Мутруга на проМника на прот МММутрался Мутить и пр
#  Iter:10 - Batch 2411/2415 - Loss:6.9056994008268915  красно прот прот проМницы и прот проМницы МироМ у кМылМо прот проМн
#  Iter:11 - Batch 2411/2415 - Loss:6.7147337993706275  кМылся на Мутился в рМоМорМался на какоМ разнакМир Мутился МутиМу и
#  Iter:12 - Batch 2411/2415 - Loss:6.5347251938917295  краснМо пропаст на водит Мутился Мутился на Мутился Мутился Мутился
#  Iter:13 - Batch 2411/2415 - Loss:6.3647103530787735  МутилМо пропаст на Мутило в рука и прМаМиром и Мутило ММутрМался Му
#  Iter:14 - Batch 2411/2415 - Loss:6.2002226168251615  Мутило Мутило прМиролько проММутило МММутролько пропасно пропасно п
#  Iter:15 - Batch 2411/2415 - Loss:6.0423692338285466  красный страну и пропасно Мирое пропасно пропасно пропасно Мирое пр
#  Iter:16 - Batch 2411/2415 - Loss:5.8889422354034075   краМны и прМирам пропаснММутро прМирам пропасно пропасно пропасно М
#  Iter:17 - Batch 2411/2415 - Loss:5.7415876525974235   Мутило и пропаснМик Мирое пропасный сМину и пропасный Мутило в рука
#  Iter:18 - Batch 2411/2415 - Loss:5.6031734161155155  Мутило МироМу тМноги и прМирану и пропасный страну и пропасМон и пр
#  Iter:19 - Batch 2411/2415 - Loss:5.4683299256202035  кМир пропаство пропаст Мутило на Мутило МироеМу тут у ним Мироед на
#  Iter:20 - Batch 2411/2415 - Loss:5.3347663733670045 пропаст на водится на водится Мутило не Маглядится в наММутММуть и
#  Iter:21 - Batch 2411/2415 - Loss:5.2076560928219495  красный страну и пропаст на водММутрел Мутило Мироед на водится на
#  Iter:22 - Batch 2411/2415 - Loss:5.0858943429152015  красный страну и пропаст на водится и прМарако пропаст на водится и
#  Iter:23 - Batch 2411/2415 - Loss:4.9612022477331595  приМел пропаст не все разниковоМу ММутило не все разниковод кусным
#  Iter:24 - Batch 2411/2415 - Loss:4.8434582217378145  Мутило на водится и красный страх, Мироед на водится у них в никако
#  Iter:25 - Batch 2411/2415 - Loss:4.7437875577989575   Мутило на выну Мироед на воМнул он на воМнулМоноМу и приМеМны и при
#  Iter:26 - Batch 2411/2415 - Loss:4.6311665864057515  как у них в нМей словой разником какМутилу Мутилу и как у них в нас
#  Iter:27 - Batch 2411/2415 - Loss:4.5380915860968086  приМертет в ним ММутило на встрет в грубительно в ним другом пропаМ
#  Iter:28 - Batch 2411/2415 - Loss:4.4452456884438215   Мутило на вМатур, а тут…    – Возны Мироед на вМатуру туда Мутилу и
#  Iter:29 - Batch 2411/2415 - Loss:4.3419201017946685  Мутило на вслух, а тут…    – Можем на встрется в руку прикруглую ку
#  Iter:30 - Batch 2411/2415 - Loss:4.2595747789948425   приМнули в разницу и пригорМи и кустил кусным другого какМетый Мути
#  Iter:31 - Batch 2411/2415 - Loss:4.1711527273247646  Мутило Мироед на всудится Мироед Мутило как у тМуй, а то луки приго
#  Iter:32 - Batch 2411/2415 - Loss:4.0958306223643055   красно ни концов лицо в ниго красно Мироед МутилоМелМы в ниго краси
#  Iter:33 - Batch 2411/2415 - Loss:4.0315336522682865   Мутилу и Многи на всякие приказываМу Мироед городобры и пригорМал б
#  Iter:34 - Batch 2411/2415 - Loss:3.9614949836486375   Мутило на люди причин тебя друг столу Мироед на Мутило как у них вМ
#  Iter:35 - Batch 2411/2415 - Loss:3.8987244024442873   крышу тебе красивать на лабку.    – Вот у ММногирался на МуММины в
#  Iter:36 - Batch 2411/2415 - Loss:3.8518221786419917   Мутило как удивляМи в руку, но все в ним ни куда Мирое Мутило как у
#  Iter:37 - Batch 2411/2415 - Loss:3.8063728970313494  красительно служу. Вот у нас Мутило, как буду, – сказал Жихарю. – С
#  Iter:38 - Batch 2411/2415 - Loss:3.7062259299713243  Мутилу. – Собрать как у нас как у нас как у нас как у нас как у нас
#  Iter:39 - Batch 2411/2415 - Loss:3.6568092039617597   привычных причинул Мутило, как будМих город, Мирое слово Мирое Мути
#  Iter:40 - Batch 2411/2415 - Loss:3.6242510695291137   красался не в Много какого кМаких предложит проМины в нМудит в тот,
#  Iter:41 - Batch 2411/2415 - Loss:3.5540099115170258   крМало в него крМало – в кусу тебе и до путники Мироед страну у них
#  Iter:42 - Batch 2411/2415 - Loss:3.4995947174260666  Мутилу. – Спину и до красно все в него красно Мара, как удивляют Му
#  Iter:43 - Batch 2411/2415 - Loss:3.4705538119793628   Мироед на Многи пригорют сМинать и прМироед столь не вскипМил Мутил
#  Iter:44 - Batch 2411/2415 - Loss:3.4730251938444343   ММин и проимМе не в руки по кним проМим трудочки принутМи как у ты
#  Iter:45 - Batch 2411/2415 - Loss:3.4040629461413205   ММутит, и волиты, но в руку не высулую куда не высуМутый судари про
#  Iter:46 - Batch 2411/2415 - Loss:3.3858283678969076  до от принуть и МногоМоришь бы у нае, и тоМих порогла в руки. И воз
#  Iter:47 - Batch 2411/2415 - Loss:3.3416543000851493   то, что ни в руМных при эти в грубок и шагов и собу ты, а туму – то
#  Iter:48 - Batch 2411/2415 - Loss:3.3309806206405272  приговорится Мирое концо, как буду, в нужный князь и на Многи пригд
#  Iter:49 - Batch 2411/2415 - Loss:3.2869348318846587  то лубой судит в трут туда еще деревут были были были быМныгибось,
#  Iter:50 - Batch 2411/2415 - Loss:3.2715726451439813   Мутилу, ни ктрене в недого Магоги прМироедМахнул и зарудо были были
#  Iter:51 - Batch 2411/2415 - Loss:3.2649213590826345  то лютом Мироед со мной и кривляю куда–нибудь и Морону кузнику.
#  Iter:52 - Batch 2411/2415 - Loss:3.2132849220418297а уж страеваться Мироеду, а тот, что лучшем Мутилу, нМагоги и концо,
#  Iter:53 - Batch 2411/2415 - Loss:3.1746708026040227   то любу у наМоне Магоги в огМнул богину, кто твои собую путу Мирое
#  Iter:54 - Batch 2411/2415 - Loss:3.1855549851951825  то любу ка Мара, а то любу ка уыль не всяких город обМастей и пропу
#  Iter:55 - Batch 2411/2415 - Loss:3.1758207972896613   то лету.    – Все луки в него вольцо слова плескам твое как буду. С
#  Iter:56 - Batch 2411/2415 - Loss:3.1687624612754715   серут Мутилу.Ма Мара, – сказал Жихарь у то люди прошептес  Колобок
#  Iter:57 - Batch 2411/2415 - Loss:3.1455251982001524   столь не поколМнулся в гновать ранул на Мироедух. Как будут?    – В
#  Iter:58 - Batch 2411/2415 - Loss:3.1047659418139277  то Мутилу за деревяшко уставляет сажМа крушку.    – Врество у ты ун
#  Iter:59 - Batch 2411/2415 - Loss:3.1099661783035584  Мутилу на концов у тыхи и страну и на в рубя заМирать нические княз
#  Iter:60 - Batch 2411/2415 - Loss:3.1105692778899015  старцы в людей обычных Мироедующе всМою глаза в друМие ли князь…
#  Iter:61 - Batch 2411/2415 - Loss:3.0928657614461142   то отказывал Жихарю. Сам туда его будеМ Мутилу – достойный судемте
#  Iter:62 - Batch 2411/2415 - Loss:3.0445927625444968   только прошепте и с от приМлюдому и поМилово слов на коня, но в Мно
#  Iter:63 - Batch 2411/2415 - Loss:3.0241363504793997   только потом, кто ты в другом подкрушился, а крушить столь Мутило н
#  Iter:64 - Batch 2411/2415 - Loss:2.9784001910325775  такие разого, а тебе и протрелан, говорится, а тебе Мутилу – кусные
#  Iter:65 - Batch 2411/2415 - Loss:3.0366140655315563   то Мара, а Мутилу старушельсМи и проМнице словно у нагие вытас и пр
#  Iter:66 - Batch 2411/2415 - Loss:2.9739944922847146   только кровью, а тебе и доМоги Мирое приМлюбо, какоМный Монах закро
#  Iter:67 - Batch 2411/2415 - Loss:2.9948603971069726 но чутьля тМнает, кто начал понимать старушится Мирое страну и латы
#  Iter:68 - Batch 2411/2415 - Loss:2.9402061106776873   красМаться, а Мутилу крМае словоМного кабать ярмалМательно устро у
#  Iter:69 - Batch 2411/2415 - Loss:2.9291249805729223   только привычуетый ноч не ММном была запроМелМательно упратно – тол
#  Iter:70 - Batch 2411/2415 - Loss:2.8507586846980762  тМут тебя и то лу и про Много кабатыМи лалоМил пальше не выкнул Жих
#  Iter:71 - Batch 2411/2415 - Loss:2.8563163688356137то луйнМе, которого…    – Мара, а круча в Многие пМаткал тества у т
#  Iter:72 - Batch 2411/2415 - Loss:2.8916263797356093   только поднял головМая ты, ведь было трубья и простой руками, говор
#  Iter:73 - Batch 2411/2415 - Loss:2.8922414507413433   тут уже не всю… Птану. Я буду кружи в научек не всю… Во всМорМне.
#  Iter:74 - Batch 2411/2415 - Loss:2.8536390337316955   самого Магого кружи поМелая тоже старик воит Монахи сМать и подняМе
#  Iter:75 - Batch 2411/2415 - Loss:2.8234550889473335   только ты не высохМургие словМой шагов у них люди по пустреми ты чт
#  Iter:76 - Batch 2411/2415 - Loss:2.8318865359069213   потому что начинать ступивляю, а то что начал Мутилу, и по рук проп
#  Iter:77 - Batch 2411/2415 - Loss:2.8157683464571325 полук не помчутый рассмотором чМе примутили. Жихарю добрых, тоже ст
#  Iter:78 - Batch 2411/2415 - Loss:2.8275418094860174   слово Мир есть.    – ВоидлаМу и проМили были мы у тушев у тушет в т
#  Iter:79 - Batch 2411/2415 - Loss:2.7920529552979664  тот, что лудом и советМался Мироедом Мироед было тут не вМество гор
#  Iter:80 - Batch 2411/2415 - Loss:2.7638744088576316   получал Жихарь. – Ни Многие мы же в рудМих разних растереб Мутилули
#  Iter:81 - Batch 2411/2415 - Loss:2.7900020924228054   только трМажды и пророки в Многобырь у том, где начал прокМудили в
#  Iter:82 - Batch 2411/2415 - Loss:2.7686606522579455   только верных шлем встрета докуда Мирое у Мрать Мироед сало таиваяс
#  Iter:83 - Batch 2411/2415 - Loss:2.7302279263507262  сМильями. И выпиМу с крыльцу у тоМи любой кинги! – в сусудем тесте
#  Iter:84 - Batch 2411/2415 - Loss:2.6931704006676518   слова пропусть не все в луда в напростоМи!    – Во втемнойо, а волп
#  Iter:85 - Batch 2411/2415 - Loss:2.6915205611861195   покМирился в стольно проспально убыл двесть кула же Мучился не всеМ
#  Iter:86 - Batch 2411/2415 - Loss:2.6926865876564507  по растернима прокомче.    – Вообще–то все выйдет Мутилу стане и мы
#  Iter:87 - Batch 2411/2415 - Loss:2.7033067083844045   получаться на шлем врострМара, Мирое, и в кууже, только Мироед? – в
#  Iter:88 - Batch 2411/2415 - Loss:2.6489908078147386   только верным. Ничего слова пМатрасно Мара, а только по раМном голо
#  Iter:89 - Batch 2411/2415 - Loss:2.6438491769294266  ту Беломо голос и с каМироводном с Мика в страху у наченькМи в недо
#  Iter:90 - Batch 2411/2415 - Loss:2.6409381273674083 он если бы на легкие привелство и лаМало и лалоту.    – В руках и с
#  Iter:91 - Batch 2411/2415 - Loss:2.6375951745769903   предложил трепит, просто откуда не Магодит, но и получать в него кр
#  Iter:92 - Batch 2411/2415 - Loss:2.6395889840254787   только верных мужие пМужило Матарь у кричМы же русами…    – Вооками
#  Iter:93 - Batch 2411/2415 - Loss:2.6121452077022806  туман в ту им почет бежал МутилоМико тайны, говори, не помнил Мутил
#  Iter:94 - Batch 2411/2415 - Loss:2.6666873110650866   в крутителя Мироедут хождеводМу и противно пМатить.    – Вои, то лю
#  Iter:95 - Batch 2411/2415 - Loss:2.5444670153441093   только круглый судьбе, теперь Магодар, мислула, – сказал Жихарь. –
#  Iter:96 - Batch 2411/2415 - Loss:2.5660730561510794   то луМился Милю, что на весные, и то люди, как бы даже в кружи Миро
#  Iter:97 - Batch 2411/2415 - Loss:2.5761876875205818   то луда, Мара, и кружится на прежник верным стМан многобы проМим, к
#  Iter:98 - Batch 2411/2415 - Loss:2.5879488461711695   словМо очень спрМаться Мироед ни концов рукМужные слуМие было ведь
#  Iter:99 - Batch 2411/2415 - Loss:2.5252491326192805  Мутило кто–то Мирое своей будут? – вМесте, все раМок, но им утыди,

# %%
print(generate_sample(n=1000, init_char='\n'))
# Out:
#    с Мироед стало быть, и вМнаМи, в трепоначить Меч и должно быть, е не выМно и процок было привисю и доМежду не поминать и с вой приезнам. – Простро и долетелМах пМутирись, а то лютежу, МироедМужился на костей – пропустил страму или же первым другой три правое схвательно все с гМруриваясь его вМестный царю, а то лютежМном теру страшная Мутилу с мМироед в тренятого кружи в тот, даже с трутренМая ты в хвательно все с груть было Мутилу с мыслимо городу Мироеда привяжеМе.
#    – Вои, Но оМиная – У крузный Монах перестал долю же в меч в царю, а то лютежут хири.
#    Жихарь у начал голоды.
#    – Вои, Но Мара, а ему Миль, и в рубаться никак будут,Муть было туда и будешь городМими и нМон становать бМоде руки птицы ли кто–то Мироед выледи в хватеМь своим: нМон стМан мои, кто такое смотрел кузнец.
#    – Вои, НМузнам. – Простро и доМет уМетру с мол, выпросто такое сморбли…» а если было ни Хоть онаете с горным столенграду в Многобор, сноМу страну и птаки в людей и Многорадуих тебе с Мироед стали и моло
